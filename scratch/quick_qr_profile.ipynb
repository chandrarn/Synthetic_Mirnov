# %%
# generate quick q(r) profile
from sys import path
# path.append('/home/rianc/Documents/eqtools-1.0/')
import eqtools as eq
from freeqdsk import geqdsk
shotno = 1160930033

eq_f = eq.CModEFIT.CModEFITTree(shotno)

# %%
dir(eq_f)
