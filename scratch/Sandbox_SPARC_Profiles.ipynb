# %%
import xarray as xr
dat = xr.open_dataset('/home/rianc/Documents/Synthetic_Mirnov/data_output/'+\
    'synthetic_spectrograms/SPARC/Spectrogram_4---3_f0.000-77.094kHz_Synth_low-n_New_Helicity.nc')

print(dat)
# Out:
# <xarray.Dataset> Size: 6MB
# Dimensions:            (frequency: 401, time: 14)
# Coordinates:
#   * frequency          (frequency) float64 3kB 0.0 1.25e+04 ... 4.988e+06 5e+06
#   * time               (time) float64 112B 0.0 8e-05 0.00016 ... 0.00096 0.00104
# Data variables: (12/270)
#     BP_IOL1_010U_real  (frequency, time) float32 22kB ...
#     BP_IOL1_010U_imag  (frequency, time) float32 22kB ...
#     BP_IOL1_010L_real  (frequency, time) float32 22kB ...
#     BP_IOL1_010L_imag  (frequency, time) float32 22kB ...
#     BP_IOL1_110U_real  (frequency, time) float32 22kB ...
#     BP_IOL1_110U_imag  (frequency, time) float32 22kB ...
#     ...                 ...
#     MRNV_340M_V8_real  (frequency, time) float32 22kB ...
#     MRNV_340M_V8_imag  (frequency, time) float32 22kB ...
#     MRNV_340M_V9_real  (frequency, time) float32 22kB ...
#     MRNV_340M_V9_imag  (frequency, time) float32 22kB ...
#     F_Mode_0           (time) float32 56B ...
# ...

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots(tight_layout=True)

ax.pcolormesh(dat.time, dat.frequency, dat.MRNV_340M_V8_real, shading='auto')

plt.show()
