# %%
import xarray as xr
import os

print(
len(os.listdir('/mnt/home/rianc/Documents/Synthetic_Mirnov/signal_generation/'+\
            '../data_output/synthetic_spectrograms/SPARC/'))
)
good = []
da = xr.open_dataset('/mnt/home/rianc/Documents/Synthetic_Mirnov/signal_generation/'+\
            '../data_output/synthetic_spectrograms/SPARC/Spectrogram_2---2_f0.000-69.936kHz_Synth_low-n_New_Helicity.nc', engine = 'scipy')

print(da)

# %%
'time' in list(da.dims) and 'frequency' in list(da.dims)

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots(tight_layout=True)

ax.pcolormesh(dat.time, dat.frequency, dat.MRNV_340M_V8_real, shading='auto')

plt.show()
